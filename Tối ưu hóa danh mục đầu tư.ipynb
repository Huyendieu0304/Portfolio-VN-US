# %% [markdown]
# TỐI ƯU HÓA DANH MỤC ĐẦU TƯ BẰNG PYTHON BẰNG CÁCH SỬ DỤNG ĐƯỜNG BIÊN HIỆU QUẢ
# (CÁC DOANH NGHIỆP VIỆT NIÊM YẾT TRÊN SÀN CHỨNG KHOÁN MỸ)
# TRÌNH BÀY BỞI: NGUYỄN THỊ HUYỀN DIỆU

# %%
import pandas_datareader.data as web
import datetime
import pandas as pd

# %%
import yfinance as yf

start = '2023-07-17'
end = '2023-11-24'
VNM = yf.download('VNM.VN', start=start, end=end)
VIC = yf.download('VIC.VN', start=start, end=end)
VCB = yf.download('VCB.VN', start=start, end=end)
HPG = yf.download('HPG.VN', start=start, end=end)
DGC = yf.download('DGC.VN', start=start, end=end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# Kiểm tra các dữ liệu có missing values hay không?
print("\nVNM missing values:\n", VNM.isnull().sum())
print("\nVIC missing values:\n", VIC.isnull().sum())
print("\nVCB missing values:\n", VCB.isnull().sum())
print("\nHPG missing values:\n", HPG.isnull().sum())
print("\nDGC missing values:\n", DGC.isnull().sum())
# Kết quả lần 1: Không có missing values
# Out:
# VNM missing values:
#  Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
# VIC missing values:
#  Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
# VCB missing values:
#  Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
# HPG missing values:
#  Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
# DGC missing values:
#  Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
Stocks = pd.concat([VNM['Adj Close'],VIC['Adj Close'],VCB['Adj Close'],HPG['Adj Close'],DGC['Adj Close']],axis=1)

# %%
Stocks.columns = ['VNM','VIC','VCB','HPG', 'DGC']
Stocks
# Out:
#                      VNM      VIC           VCB      HPG           DGC
# Date
# 2023-07-17  71768.382812  52900.0  88738.359375  27300.0  69116.414062
# 2023-07-18           NaN      NaN  88314.984375      NaN           NaN
# 2023-07-19  72066.179688  52100.0  90177.812500  27400.0  68729.210938
# 2023-07-20  72066.179688  52000.0  88907.703125  28200.0  70568.445312
# 2023-07-21  72959.554688  52100.0  88907.703125  28400.0  70665.242188
# ...                  ...      ...           ...      ...           ...
# 2023-11-17  69485.296875  42200.0  85600.000000  26500.0  90315.992188
# 2023-11-20  68790.437500  42700.0  86100.000000  26650.0  90315.992188
# 2023-11-21  68988.968750  42600.0  86600.000000  27050.0  91864.820312
# 2023-11-22  68889.703125  42000.0  86700.000000  27200.0  93123.242188
# 2023-11-23  68194.851562  41300.0  85500.000000  25850.0  89928.781250
#
# [87 rows x 5 columns]

# %%
# Nhưng kết quả hiện phía trên cho chúng ta thấy rằng có missing values
# Để chắc chắn hơn tôi sẽ tải bản csv để kiểm tra
# Kết luận:
# Các giá trị bị thiếu trong file csv của tôi được biểu thị bằng chuỗi "null" thay vì giá trị NaN (Không phải số) thực tế mà Pandas thường sử dụng cho dữ liệu bị thiếu hoặc không xác định.

# %%
# Thực hiện các bước như sau để xử lý missing values:

# %%
# Load the data from the CSV file
VNM = r'C:\Users\huyen\Downloads\Python CK\VNM.VN.csv'  # Update with the actual path to your file
df = pd.read_csv(VNM, parse_dates=['Date'], index_col='Date')

# Replace "null" with NaN
df.replace('null', pd.NA, inplace=True)

# Check for missing values
print("Missing values:\n", df.isna().sum())

# Save the DataFrame to a new CSV file
VNM_NEW = r'C:\Users\huyen\Downloads\Python CK\VNM.VN_cleaned.csv'  # Update with the desired path
df.to_csv(VNM_NEW)
vnm = pd.read_csv(VNM_NEW, parse_dates=['Date'], index_col='Date')
# Out:
# Missing values:
#  Open         8
# High         8
# Low          8
# Close        8
# Adj Close    8
# Volume       8
# dtype: int64

# %%
# Load the data from the CSV file
VIC = r'C:\Users\huyen\Downloads\Python CK\VIC.VN.csv'  # Update with the actual path to your file
df = pd.read_csv(VIC, parse_dates=['Date'], index_col='Date')

# Replace "null" with NaN
df.replace('null', pd.NA, inplace=True)

# Check for missing values
print("Missing values:\n", df.isna().sum())

# Save the DataFrame to a new CSV file
VIC_NEW = r'C:\Users\huyen\Downloads\Python CK\VIC.VN_cleaned.csv'  # Update with the desired path
df.to_csv(VIC_NEW)
vic = pd.read_csv(VIC_NEW, parse_dates=['Date'], index_col='Date')
# Out:
# Missing values:
#  Open         8
# High         8
# Low          8
# Close        8
# Adj Close    8
# Volume       8
# dtype: int64

# %%
# Load the data from the CSV file
VCB = r'C:\Users\huyen\Downloads\Python CK\VCB.VN.csv'  # Update with the actual path to your file
df = pd.read_csv(VCB, parse_dates=['Date'], index_col='Date')

# Replace "null" with NaN
df.replace('null', pd.NA, inplace=True)

# Check for missing values
print("Missing values:\n", df.isna().sum())

# Save the DataFrame to a new CSV file
VCB_NEW = r'C:\Users\huyen\Downloads\Python CK\VCB.VN_cleaned.csv'  # Update with the desired path
df.to_csv(VCB_NEW)
vcb = pd.read_csv(VCB_NEW, parse_dates=['Date'], index_col='Date')
# Out:
# Missing values:
#  Open         7
# High         7
# Low          7
# Close        7
# Adj Close    7
# Volume       7
# dtype: int64

# %%
# Load the data from the CSV file
HPG = r'C:\Users\huyen\Downloads\Python CK\HPG.VN.csv'  # Update with the actual path to your file
df = pd.read_csv(HPG, parse_dates=['Date'], index_col='Date')

# Replace "null" with NaN
df.replace('null', pd.NA, inplace=True)

# Check for missing values
print("Missing values:\n", df.isna().sum())

# Save the DataFrame to a new CSV file
HPG_NEW = r'C:\Users\huyen\Downloads\Python CK\HPG.VN_cleaned.csv'  # Update with the desired path
df.to_csv(HPG_NEW)
hpg = pd.read_csv(HPG_NEW, parse_dates=['Date'], index_col='Date')
# Out:
# Missing values:
#  Open         8
# High         8
# Low          8
# Close        8
# Adj Close    8
# Volume       8
# dtype: int64

# %%
# Load the data from the CSV file
DGC = r'C:\Users\huyen\Downloads\Python CK\DGC.VN.csv'  # Update with the actual path to your file
df = pd.read_csv(DGC, parse_dates=['Date'], index_col='Date')

# Replace "null" with NaN
df.replace('null', pd.NA, inplace=True)

# Check for missing values
print("Missing values:\n", df.isna().sum())

# Save the DataFrame to a new CSV file and read it into a new DataFrame
DGC_NEW = r'C:\Users\huyen\Downloads\Python CK\DGC.VN_cleaned.csv'  # Update with the desired path
df.to_csv(DGC_NEW)
dgc = pd.read_csv(DGC_NEW, parse_dates=['Date'], index_col='Date')
# Out:
# Missing values:
#  Open         8
# High         8
# Low          8
# Close        8
# Adj Close    8
# Volume       8
# dtype: int64

# %%
# Kiểm tra dữ liệu có cho ra kết quả có missing values như kỳ vọng hay không?
dgc
# Out:
#                Open     High      Low    Close  Adj Close     Volume
# Date
# 2023-07-17  72000.0  72600.0  71200.0  71400.0    71400.0  2340400.0
# 2023-07-18      NaN      NaN      NaN      NaN        NaN        NaN
# 2023-07-19  71000.0  71800.0  70500.0  71000.0    71000.0  2835400.0
# 2023-07-20  71200.0  73500.0  71200.0  72900.0    72900.0  5116900.0
# 2023-07-21  73100.0  73900.0  72800.0  73000.0    73000.0  3264000.0
# ...             ...      ...      ...      ...        ...        ...
# 2023-11-20  91300.0  94200.0  91300.0  93300.0    93300.0  1839700.0
# 2023-11-21  94500.0  95000.0  93500.0  94900.0    94900.0  2232100.0
# 2023-11-22  95500.0  97900.0  95200.0  96200.0    96200.0  3916500.0
# 2023-11-23  96900.0  97000.0  92900.0  92900.0    92900.0  3467700.0
# 2023-11-24  93800.0  95500.0  91300.0  95500.0    95500.0  3115600.0
#
# [95 rows x 6 columns]

# %%
# Cách xử lý dữ liệu có missing values
# Thay thế các missing values bằng giá đóng cửa của ngày trước đó
vnm.fillna(value=vnm.shift(1), inplace=True)
# Kiểm tra dữ liệu còn missing values hay không?
vnm
# Out:
#                Open     High      Low    Close  Adj Close     Volume
# Date
# 2023-07-17  73000.0  73600.0  72200.0  72300.0    72300.0  5802800.0
# 2023-07-18  73000.0  73600.0  72200.0  72300.0    72300.0  5802800.0
# 2023-07-19  72500.0  73000.0  72400.0  72600.0    72600.0  3025100.0
# 2023-07-20  72600.0  72800.0  72300.0  72600.0    72600.0  2600707.0
# 2023-07-21  72600.0  73500.0  72500.0  73500.0    73500.0  3821822.0
# ...             ...      ...      ...      ...        ...        ...
# 2023-11-20  69200.0  69900.0  69000.0  69300.0    69300.0  2001000.0
# 2023-11-21  69400.0  69800.0  68900.0  69500.0    69500.0  2989800.0
# 2023-11-22  69500.0  70200.0  69000.0  69400.0    69400.0  1533200.0
# 2023-11-23  69800.0  69900.0  68700.0  68700.0    68700.0  1653100.0
# 2023-11-24  68600.0  68900.0  67600.0  68300.0    68300.0  3128900.0
#
# [95 rows x 6 columns]

# %%
# Áp dụng cho các dữ liệu khác
vic.fillna(value=vic.shift(1), inplace=True)
vcb.fillna(value=vcb.shift(1), inplace=True)
hpg.fillna(value=hpg.shift(1), inplace=True)	
dgc.fillna(value=dgc.shift(1), inplace=True)

# %%
# Bây giờ các có thể thao tác các bước còn lại
stocks = pd.concat([vnm['Adj Close'],vic['Adj Close'],vcb['Adj Close'],hpg['Adj Close'],dgc['Adj Close']],axis=1)
stocks
stocks.columns = ['VNM','VIC','VCB', 'HPG', 'DGC']
stocks.columns
# Out:
# Index(['VNM', 'VIC', 'VCB', 'HPG', 'DGC'], dtype='object')

# %%
stocks
# Out:
#                 VNM      VIC          VCB      HPG      DGC
# Date
# 2023-07-17  72300.0  52900.0  88738.35938  27300.0  71400.0
# 2023-07-18  72300.0  52900.0  88314.98438  27300.0  71400.0
# 2023-07-19  72600.0  52100.0  90177.81250  27400.0  71000.0
# 2023-07-20  72600.0  52000.0  88907.70313  28200.0  72900.0
# 2023-07-21  73500.0  52100.0  88907.70313  28400.0  73000.0
# ...             ...      ...          ...      ...      ...
# 2023-11-20  69300.0  42700.0  86100.00000  26650.0  93300.0
# 2023-11-21  69500.0  42600.0  86600.00000  27050.0  94900.0
# 2023-11-22  69400.0  42000.0  86700.00000  27200.0  96200.0
# 2023-11-23  68700.0  41300.0  85500.00000  25850.0  92900.0
# 2023-11-24  68300.0  41350.0  86000.00000  26400.0  95500.0
#
# [95 rows x 5 columns]

# %% [markdown]
# VẼ ĐỒ THỊ GIÁ ĐÓNG CỬA ĐIỀU CHỈNH

# %%
import matplotlib.pyplot as plt

# %%
monthly_stocks = stocks.resample('M').last()

plt.figure(figsize=(14, 7))

for column in monthly_stocks.columns:
    plt.plot(monthly_stocks.index, monthly_stocks[column], label=column, linewidth=3.5)

plt.title('Giá đóng cửa điều chỉnh hàng tháng của các cổ phiếu (07/2023 - 11/2023)', fontsize=16, fontweight='bold')
plt.xlabel('Ngày', fontsize=14)
plt.ylabel('Giá đóng của điều chỉnh', fontsize=14)
plt.legend(loc='upper left', fontsize=12)
plt.grid(False)  # Turn off the grid lines
plt.show()

# %% [markdown]
# BẢN ĐỒ NHIỆT (HEAT MAP)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
correlation_matrix = stocks.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5, annot_kws={"weight": "bold"}, cbar_kws={'format': '%.2f'})
plt.title('Bản đồ nhiệt thể hiện sự tương quan các giá đóng cửa điều chỉnh')
plt.show()

# %% [markdown]
# MA TRẬN HIỆP PHƯƠNG SAI

# %%
import numpy as np

# %%
# Log của phần trăm thay đổi
cov_matrix = stocks.pct_change().apply(lambda x: np.log(1+x)).cov()
cov_matrix
# Out:
# C:\Users\huyen\AppData\Local\Temp\ipykernel_13444\4046138525.py:2: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   cov_matrix = stocks.pct_change().apply(lambda x: np.log(1+x)).cov()
#           VNM           VIC           VCB       HPG       DGC
# VNM  0.000223  6.138508e-06  9.267869e-05  0.000153  0.000116
# VIC  0.000006  9.290922e-04 -2.317837e-07  0.000191  0.000276
# VCB  0.000093 -2.317837e-07  1.576588e-04  0.000090  0.000060
# HPG  0.000153  1.905666e-04  8.950656e-05  0.000472  0.000310
# DGC  0.000116  2.759887e-04  5.965107e-05  0.000310  0.000676

# %% [markdown]
# LỢI NHẬN KỲ VỌNG DANH MỤC ĐẦU TƯ

# %%
ind_er = stocks.resample('M').last().pct_change().mean() * 12
ind_er
# Out:
# VNM   -0.360752
# VIC   -0.462893
# VCB   -0.231328
# HPG   -0.148457
# DGC    0.982758
# dtype: float64

# %% [markdown]
# TỐI ƯU HÓA DANH MỤC ĐẦU TƯ BẰNG CÁCH SỬ DỤNG ĐƯỜNG BIÊN HIỆU QUẢ

# %%
ann_sd = stocks.pct_change().apply(lambda x: np.log(1+x)).std() * np.sqrt(12)
ann_sd
# Out:
# C:\Users\huyen\AppData\Local\Temp\ipykernel_13444\2925016654.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   ann_sd = stocks.pct_change().apply(lambda x: np.log(1+x)).std() * np.sqrt(12)
# VNM    0.051687
# VIC    0.105589
# VCB    0.043496
# HPG    0.075299
# DGC    0.090066
# dtype: float64

# %%
assets = pd.concat([ind_er, ann_sd], axis=1) # Tạo bảng để trực quan hóa lợi nhuận và sự biến động của tài sản
assets.columns = ['Returns', 'Volatility']
assets
# Out:
#       Returns  Volatility
# VNM -0.360752    0.051687
# VIC -0.462893    0.105589
# VCB -0.231328    0.043496
# HPG -0.148457    0.075299
# DGC  0.982758    0.090066

# %%
p_ret = [] # Xác định một mảng trống cho lợi nhuận danh mục đầu tư
p_vol = [] # Xác định một mảng trống cho sự biến động của danh mục đầu tư
p_weights = [] # Xác định một mảng trống cho trọng số tài sản (asset weights)

# Chạy vòng lặp này 10000 lần
num_assets = len(stocks.columns)
num_portfolios = 10000
np.random.seed(42)

# %%
p_weights = []
p_ret = []
p_vol = []

for portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights /= np.sum(weights)
    p_weights.append(weights)
    
    returns = np.dot(weights, ind_er)
    p_ret.append(returns)
    
    covar = cov_matrix.mul(weights, axis=0).mul(weights, axis=1).sum().sum()
    sd = np.sqrt(covar)
    
    ann_sd = sd * np.sqrt(12)
    p_vol.append(ann_sd)

# %%
data = {'Returns':p_ret, 'Volatility':p_vol}
for counter, symbol in enumerate(stocks.columns.tolist()):
    data[symbol+' weight'] = [w[counter] for w in p_weights]

# %%
portfolios  = pd.DataFrame(data)
portfolios.head() # Khung dữ liệu của 10000 danh mục đầu tư được tạo
# Out:
#     Returns  Volatility  VNM weight  VIC weight  VCB weight  HPG weight  \
# 0 -0.129067    0.040538    0.292506    0.045677    0.419308    0.127059
# 1 -0.222989    0.047022    0.200749    0.236102    0.251720    0.255572
# 2  0.069521    0.047389    0.311437    0.037779    0.226417    0.146138
# 3  0.004321    0.050526    0.405411    0.131131    0.043811    0.168848
# 4 -0.011998    0.055102    0.057908    0.218295    0.184282    0.333839
#
#    DGC weight
# 0    0.115450
# 1    0.055856
# 2    0.278229
# 3    0.250799
# 4    0.205676

# %%
# Vẽ đường biên hiệu quả
portfolios.plot.scatter(x='Volatility', y='Returns', marker='o', s=10, alpha=0.3, grid=True, figsize=[10,10])
# Out:
# <Axes: xlabel='Volatility', ylabel='Returns'>

# %% [markdown]
# DANH MỤC BIẾN ĐỘNG TỐI THIỂU (MINIMUM VOLATILITY PORTFOLIO)

# %%
min_vol_port = portfolios.iloc[portfolios['Volatility'].idxmin()]
# idxmin() cung cấp cho tôi giá trị tối thiểu trong cột được chỉ định                           
min_vol_port
# Out:
# Returns      -0.304028
# Volatility    0.037858
# VNM weight    0.320860
# VIC weight    0.136744
# VCB weight    0.541743
# HPG weight    0.000266
# DGC weight    0.000387
# Name: 5483, dtype: float64

# %%
# Vẽ sơ đồ danh mục biến động tối thiểu
plt.subplots(figsize=[10,10])
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)
# Out:
# C:\Users\huyen\AppData\Local\Temp\ipykernel_13444\206028373.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)

# %% [markdown]
# DANH MỤC RỦI RO TỐI ƯU (OPTIMAL RISKY PORTFOLIO)

# %%
# Tìm danh mục rủi ro tối ưu
rf = 0.01 # Yếu tố rủi ro
optimal_risky_port = portfolios.iloc[((portfolios['Returns']-rf)/portfolios['Volatility']).idxmax()]
optimal_risky_port
# Out:
# Returns       0.720957
# Volatility    0.079861
# VNM weight    0.019363
# VIC weight    0.088392
# VCB weight    0.005741
# HPG weight    0.089315
# DGC weight    0.797190
# Name: 3647, dtype: float64

# %%
# Trích xuất trọng số từ danh mục rủi ro tối ưu
vnm_weight = optimal_risky_port['VNM weight']
vic_weight = optimal_risky_port['VIC weight']
vcb_weight = optimal_risky_port['VCB weight']
hpg_weight = optimal_risky_port['HPG weight']
dgc_weight = optimal_risky_port['DGC weight']

# Tên các tài sản
assets = ['VNM', 'VIC', 'VCB', 'HPG', 'DGC']

# Trọng số tương ứng
weights = [vnm_weight, vic_weight, vcb_weight, hpg_weight, dgc_weight]

# Vẽ biểu đồ hình tròn như sau
fig, ax = plt.subplots(figsize=(8, 7))
pie = ax.pie(weights, labels=assets, autopct='%1.1f%%', startangle=140)
ax.legend(pie[0], assets, loc="center left", bbox_to_anchor=(1, 0.5))
plt.title('Phân bổ danh mục đầu tư')
plt.show()

# %%
# Lập danh mục rủi ro tối ưu
plt.subplots(figsize=(10, 8))
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)
plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color='g', marker='*', s=500)
# Out:
# C:\Users\huyen\AppData\Local\Temp\ipykernel_13444\344689983.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)
# C:\Users\huyen\AppData\Local\Temp\ipykernel_13444\344689983.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color='g', marker='*', s=500)

# %%
# Ngôi sao đỏ biểu thị danh mục đầu tư hiệu quả nhất với độ biến động tối thiểu.
# Ngôi sao màu xanh lá cây đại diện cho danh mục rủi ro tối ưu.

# %% [markdown]
# HẾT
